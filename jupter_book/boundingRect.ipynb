# %%
import cv2

# %%
from PIL import Image, ImageDraw, ImageFilter

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('test.jpg', -1)

# %%
rgba = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgba)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(gray)

# %%
ret, mask = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU + cv2.THRESH_BINARY_INV)

# %%
plt.imshow(mask)

# %%
cv2.imwrite("tttt.png", mask)
# Out:
# True

# %%
imgrgb = Image.open('test.jpg')

# %%
imgrgb
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=104x28 at 0x1179EBD90>

# %%
im_a = Image.open("tttt.png").convert('L')

# %%
im_a
# Out:
# <PIL.Image.Image image mode=L size=104x28 at 0x11AEA7AC0>

# %%
imgrgb.putalpha(im_a)

# %%
plt.imshow(mask)

# %%
contours, hie = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
tmp = img.copy()
cv2.drawContours(tmp, contours, -1, (0, 255, 0), 1)
# Out:
# array([[[233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        ...,
#
#        [[233, 231, 231],
#         [233, 231, 231],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 231],
#         [233, 231, 231],
#         [233, 231, 231],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 231],
#         [233, 231, 231],
#         [233, 231, 231],
# ...

# %%
plt.imshow(tmp)

# %%
print(len(contours))
# Out:
# 3

# %%
t = img.copy()

# %%
t = img.copy()
cv2.drawContours(t, contours, -1, (0, 255, 0), 1)
# Out:
# array([[[233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        ...,
#
#        [[233, 231, 231],
#         [233, 231, 231],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 231],
#         [233, 231, 231],
#         [233, 231, 231],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 231],
#         [233, 231, 231],
#         [233, 231, 231],
# ...

# %%
plt.imshow(t)

# %%
x, y, w, h = cv2.boundingRect(contours[0])
red = (0, 0, 255)

# %%
t = img.copy()
cv2.rectangle(t, (x, y), (x+w, y+h), red, 2)
# Out:
# array([[[233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        ...,
#
#        [[233, 231, 231],
#         [233, 231, 231],
#         [233, 231, 230],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 231],
#         [233, 231, 231],
#         [233, 231, 231],
#         ...,
#         [233, 231, 230],
#         [233, 231, 230],
#         [233, 231, 230]],
#
#        [[233, 231, 231],
#         [233, 231, 231],
#         [233, 231, 231],
# ...

# %%
plt.imshow(t)

# %%
print(x, y, x+w, y+h)
# Out:
# 22 4 42 24

# %%
plt.imshow(img)

# %%
width =x + w
height = y + h

# %%
tmp = img.copy()

# %%
plt.imshow(tmp)

# %%
roi = img[y:height, x:width]

# %%
plt.imshow(roi)

# %%
cv2.imwrite('char2.png', roi)
# Out:
# True

# %%
mask_img = cv2.imread("test/data/test_mask.png")

# %%
plt.imshow(mask_img)

# %%
contours, his = cv2.findContours(mask_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-273-0e5967a681ff> in <module>
# ----> 1 contours, his = cv2.findContours(mask_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#
# error: OpenCV(4.5.3) /private/var/folders/24/8k48jl6d249_n_qfxwsl6xvm0000gn/T/pip-req-build-vy_omupv/opencv/modules/imgproc/src/contours.cpp:197: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'

# %%
money = cv2.imread("81kFyB+ZAfL.jpg", -1)

# %%
plt.imshow(money)

# %%
moeny_gray = cv2.cvtColor(money, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(moeny_gray)

# %%
ret, money_mask = cv2.threshold(moeny_gray, 0, 255, cv2.THRESH_OTSU + cv2.THRESH_BINARY_INV)

# %%
plt.imshow(money_mask)

# %%
contours, his = cv2.findContours(money_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
img_t = money.copy()

# %%
plt.imshow(img_t)

# %%
print(len(contours))
red = (0, 0, 255)
# Out:
# 376

# %%
for i, con in enumerate(contours):
    x, y, w, h = cv2.boundingRect(con)
    if h > 100:
        cv2.rectangle(img_t, (x, y), (x+w, y+h), red, 2)
        roi = money[y:y+h, x:x+w]
        cv2.imwrite(os.path.join("result", str(i) + ".png"), roi)

# %%
cv2.imwrite("bounding_img.png", img_t)
# Out:
# True

# %%
t = cv2.imread('test.jpg')
plt.imshow(t)

# %%
t = cv2.imread('test.jpg')
plt.imshow(t)

# %%
src = cv2.cvtColor(t, cv2.COLOR_RGB2BGR)
plt.imshow(t)

# %%
g = cv2.cvtColor(t, cv2.COLOR_RGB2GRAY)
plt.imshow(cv2.cvtColor(g, cv2.COLOR_RGB2BGR))

# %%
ret, th = cv2.threshold(g, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
plt.imshow(cv2.cvtColor(th, cv2.COLOR_RGB2BGR))

# %%
cv2.imwrite("test_mask.png", th)
# Out:
# True

# %%
mask = cv2.imread("test_mask.png", -1)
plt.imshow(cv2.cvtColor(mask, cv2.COLOR_RGB2BGR))

# %%
contours, hieracy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
len(contours)
# Out:
# 3

# %%
print(contours)
# Out:
# [array([[[47,  4]],
#
#        [[46,  5]],
#
#        [[46, 19]],
#
#        [[47, 20]],
#
#        [[47, 21]],
#
#        [[49, 23]],
#
#        [[52, 23]],
#
#        [[53, 22]],
#
#        [[55, 22]],
#
#        [[56, 21]],
#
#        [[57, 21]],
#
#        [[60, 18]],
#
#        [[60, 16]],
#
#        [[59, 15]],
#
#        [[59, 16]],
#
#        [[54, 21]],
#
#        [[49, 21]],
#
#        [[48, 20]],
#
#        [[48,  4]]], dtype=int32), array([[[25,  4]],
#
#        [[24,  5]],
#
#        [[24, 11]],
#
#        [[29, 11]],
#
#        [[30, 12]],
#
#        [[30, 19]],
#
#        [[29, 20]],
#
#        [[27, 18]],
#
#        [[27, 14]],
#
#        [[25, 14]],
#
#        [[25, 17]],
#
#        [[24, 18]],
#
#        [[24, 19]],
#
#        [[23, 20]],
#
#        [[23, 21]],
#
#        [[22, 22]],
#
#        [[22, 23]],
#
#        [[23, 23]],
#
#        [[26, 20]],
#
#        [[27, 20]],
#
#        [[29, 22]],
#
#        [[30, 22]],
#
#        [[31, 23]],
#
#        [[40, 23]],
# ...

# %%
x, y, w, h = cv2.boundingRect(contours[0])
max_w = min_w = w
max_h = min_h = h
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    if(w < min_w):
        min_w = w
    elif(w > max_w):
        max_w = w
    if(h < min_h):
        min_h = h
    elif(h > max_h):
        max_h = h
